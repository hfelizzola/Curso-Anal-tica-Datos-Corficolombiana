# %% [markdown]
# <a href="https://colab.research.google.com/github/hfelizzola/Curso-Anal-tica-Datos-Corficolombiana/blob/main/Analisis_Exploratorio_de_Datos_Caso_V%C3%ADas_Rurales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis Exploratorio de Datos

# %% [markdown]
# ## Caso: Análisis de Riesgos de Sobrecostos y Demoras en Proyectos de Vías Rurales en Colombia
#
# En el desarrollo de proyectos de vías rurales en Colombia, es común enfrentarse a riesgos de retrasos y sobrecostos que impactan negativamente su finalización y presupuesto. Estos riesgos pueden surgir por diversas razones, como condiciones geográficas, ineficiencias en el proceso de contratación, cambios en los materiales, factores climáticos, y problemas administrativos o financieros. El objetivo es desarrollar un análisis exploratorio de datos de contratación pública para proyectos de vías con el fin de entender el riesgo de que un proyecto incurra en retrasos en el tiempo de ejecución o sobrecostos con respecto a la cuantía inicialmente acordada y factores asociados a estos riesgos.
#
# El análisis pretende extraer información clave y útil para las entidades gubernamentales y contratistas en la identificación temprana de proyectos con alto riesgo de desviaciones. Esto facilitará la implementación de medidas preventivas y correctivas para garantizar la ejecución oportuna y eficiente de los recursos. Para lograrlo, se cuenta con un conjunto de datos históricos sobre contratos para la construcción, rehabilitación, mejoramiento y mantenimiento de vías rurales, que contiene información financiera, contractual y de ejecución de cada proyecto.

# %% [markdown]
# ## Configuración inicial del notebook

# %% [markdown]
# Antes de comenzar el proceso de análisis exploratorio de los datos debe asegurar que las librerias esten cargadas y la carpeta de trabajo este configurada.

# %%
# Librerias para Ciencia de Datos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

pd.set_option('display.max_columns',None)
warnings.filterwarnings('ignore')

# %% [markdown]
# Dentro de la carpeta de google colab deben crear una carpeta con el nombre`Curso Corficolombiana`.

# %%
# Conectar con carpeta de Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Setup working directory
os.chdir('/content/drive/MyDrive/Colab Notebooks/Curso Corficolombiana')
# !ls
# Out:
# Mounted at /content/drive
# 'Analisis Exploratorio de Datos - Caso Vías Rurales.ipynb'
#  vias_rurales_secop_i_raw_data_v13082024.csv

# %% [markdown]
# ## Exploración y entendimiento de los datos

# %% [markdown]
# La fase de exploración y entendimiento de los datos tiene como objetivo identificar y comprender las características de las variables que podrían influir en las desviaciones en tiempo y costo de los proyectos de vías rurales. En esta etapa, se busca *detectar patrones, relaciones y posibles problemas en los datos, como valores atípicos o faltantes, que podrían afectar el análisis posterior*. Las tareas básicas incluyen:
#
# * Entender las desviaciones en tiempo y costo de los proyectos de vías rurales
# * Examinar la distribución de las características de los contratos
# * Analizar la relación entre las características del contrato y con las desviaciones en tiempo y costo en proyectos de vías rurales

# %% [markdown]
# ### Cargar y revisar la estructura de los datos

# %%
# Carga de datos
datos = pd.read_csv('vias_rurales_secop_i_raw_data_v13082024.csv')

# Revisa las primeras y últimas filas para tener una idea general de los registros
datos.head(5)
# Out:
#                        uid                           nombre_de_la_entidad  \
# 0     15-4-4221275-3896250   LA GUAJIRA - ALCALDIA MUNICIPIO DE BARRANCAS
# 1    15-11-4173928-3984265  SANTANDER - ALCALDIA MUNICIPIO DE PIEDECUESTA
# 2  21-11-12612688-12021477     CUNDINAMARCA - ALCALDIA MUNICIPIO DE FOSCA
# 3   20-11-10445399-9709897       BOYACA - ALCALDIA MUNICIPIO DE PACHAVITA
# 4     20-21-20342-10910037         BOYACA - ALCALDIA MUNICIPIO DE CHIVATA
#
#   departamento_entidad                            orden_entidad  \
# 0           LA GUAJIRA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 1            SANTANDER  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 4
# 2         CUNDINAMARCA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 3               BOYACA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 4               BOYACA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
#
#                                            modalidad  \
# 0                                   REGIMEN ESPECIAL
# 1  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 2  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 3  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 4                            LICITACION OBRA PUBLICA
#
#   causal_contratacion_directa                       objeto_a_contratar  \
# 0                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 1                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 2                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 3                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 4                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
#
#                                       detalle_objeto  cuantia_proceso  \
# 0  MEJORAMIENTO Y ADECUACION DE LAS VIAS EXISTENT...         51960000
# 1  MEJORAMIENTO DE LAS VIAS TERCIARIAS DE LA VERE...        149999947
# 2  MEJORAMIENTO DE LA VIA QUE COMUNICA DESDE EL P...        150000000
# 3  MANTENIMIENTO Y MEJORAMIENTO VIAS VEREDALES EN...        162103043
# 4  MEJORAMIENTO DE LA VIA AVENIDA JIMENEZ - PONTE...        467516765
#
#    cuantia_contrato  valor_total_de_adiciones  valor_contrato_con_adiciones  \
# 0          51960000                         0                      51960000
# 1         149999946                         0                     149999946
# 2         142967967                         0                     142967967
# 3         162084746                  75000000                     237084746
# 4         441787828                 158201644                     599989472
#
#    anno_firma              fecha_firma  fecha_ini_ejec_contrato  \
# 0        2015  2015-04-28T00:00:00.000  2015-05-12T00:00:00.000
# 1        2015  2015-10-19T00:00:00.000  2015-10-19T00:00:00.000
# 2        2022  2022-03-17T00:00:00.000  2022-07-01T00:00:00.000
# 3        2020  2020-03-10T00:00:00.000  2020-04-01T00:00:00.000
# 4        2021  2021-03-08T00:00:00.000  2021-03-11T00:00:00.000
#
#    plazo_de_ejec_del_contrato rango_de_ejec_del_contrato  \
# 0                           2                          M
# 1                           2                          M
# 2                           8                          M
# 3                           3                          M
# 4                           1                          M
#
#    tiempo_adiciones_en_dias  tiempo_adiciones_en_meses  \
# 0                         0                          0
# 1                         0                          0
# 2                         0                          0
# 3                        45                          0
# 4                         0                          1
#
#    fecha_fin_ejec_contrato  id_adjudicacion  \
# 0  2015-07-12T00:00:00.000          3896250
# 1  2015-12-19T00:00:00.000          3984265
# 2  2023-03-01T00:00:00.000         12021477
# 3  2020-08-01T00:00:00.000          9709897
# 4  2021-05-11T00:00:00.000         10910037
#
#                                           urlproceso nit_de_la_entidad  \
# 0  {'url': 'https://www.contratos.gov.co/consulta...       800099223-3
# 1  {'url': 'https://www.contratos.gov.co/consulta...       817000992-5
# 2  {'url': 'https://www.contratos.gov.co/consulta...         899999420
# 3  {'url': 'https://www.contratos.gov.co/consulta...         800028461
# 4  {'url': 'https://www.contratos.gov.co/consulta...       800014989-1
#
#   identificacion_del_contratista dpto_y_muni_contratista municipio_entidad  \
# 0                    900514557-1              LA GUAJIRA         BARRANCAS
# 1                     9008974759               SANTANDER       PIEDECUESTA
# 2                      901089904            CUNDINAMARCA             FOSCA
# 3                      900485495                  BOYACA         PACHAVITA
# 4                      901451682                  BOYACA           CHIVATA
#
#               nom_razon_social_contratista estado_del_proceso
# 0  ASOCIACION DE CAFICULTORES DE BARRANCAS          LIQUIDADO
# 1            UNION TEMPORAL  HUELLAS  2015          LIQUIDADO
# 2                     CONTRUCTORA PG S.A.S          LIQUIDADO
# 3        SAGA S.A.S, CONSTRUIMOS EL FUTURO          LIQUIDADO
# 4              UNION TEMPORAL CHIVATA 2020          LIQUIDADO

# %%
# últimas 5 filas
datos.tail(5)
# Out:
#                          uid                           nombre_de_la_entidad  \
# 974    15-11-4158615-3916756  SANTANDER - ALCALDIA MUNICIPIO DE PIEDECUESTA
# 975    19-13-9651959-8811107        ANTIOQUIA - ALCALDIA MUNICIPIO DE OLAYA
# 976  21-13-11996798-11158224       TOLIMA - ALCALDIA MUNICIPIO DE CHAPARRAL
# 977    19-11-9968957-9216325          BOYACA - ALCALDIA MUNICIPIO DE SAMACA
# 978      19-21-12467-9123539    ANTIOQUIA - ALCALDIA MUNICIPIO DE ANGOSTURA
#
#     departamento_entidad                            orden_entidad  \
# 974            SANTANDER  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 4
# 975            ANTIOQUIA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 976               TOLIMA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 977               BOYACA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 978            ANTIOQUIA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
#
#                                              modalidad  \
# 974  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 975                        CONTRATACION MINIMA CUANTIA
# 976                        CONTRATACION MINIMA CUANTIA
# 977  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 978                            LICITACION OBRA PUBLICA
#
#     causal_contratacion_directa                       objeto_a_contratar  \
# 974                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 975                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 976                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 977                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 978                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
#
#                                         detalle_objeto  cuantia_proceso  \
# 974  MEJORAMIENTO DE LAS VIAS TERCIARIAS DE LA VERE...         36980184
# 975  MANTENIMIENTO PREVENTIVO DE LA VIA TERCIARIA Q...         23000000
# 976  MANTENIMIENTO PUENTE PARA CAMINO DE HERRADURA ...         25400813
# 977  CONSTRUCCION DE PLACA HUELLA PARA EL ACCESO AL...         81326035
# 978  CONSTRUCCION A TODO COSTO DE UN (1) KILOMETRO ...        398344885
#
#      cuantia_contrato  valor_total_de_adiciones  valor_contrato_con_adiciones  \
# 974          36980171                         0                      36980171
# 975          23000000                         0                      23000000
# 976          25340900                         0                      25340900
# 977          81315081                         0                      81315081
# 978         398330315                  62400000                     460730315
#
#      anno_firma              fecha_firma  fecha_ini_ejec_contrato  \
# 974        2015  2015-09-18T00:00:00.000  2015-09-18T00:00:00.000
# 975        2019  2019-07-10T00:00:00.000  2019-07-15T00:00:00.000
# 976        2021  2021-06-09T00:00:00.000  2021-06-11T00:00:00.000
# 977        2019  2019-11-13T00:00:00.000  2019-11-15T00:00:00.000
# 978        2019  2019-09-16T00:00:00.000  2019-10-16T00:00:00.000
#
#      plazo_de_ejec_del_contrato rango_de_ejec_del_contrato  \
# 974                           1                          M
# 975                          20                          D
# 976                          45                          D
# 977                          20                          D
# 978                           2                          M
#
#      tiempo_adiciones_en_dias  tiempo_adiciones_en_meses  \
# 974                         0                          0
# 975                         0                          0
# 976                         0                          0
# 977                         0                          0
# 978                        30                          5
#
#      fecha_fin_ejec_contrato  id_adjudicacion  \
# 974  2015-10-18T00:00:00.000          3916756
# 975  2019-08-04T00:00:00.000          8811107
# 976  2021-07-26T00:00:00.000         11158224
# 977  2019-12-05T00:00:00.000          9216325
# 978  2020-06-16T00:00:00.000          9123539
#
#                                             urlproceso nit_de_la_entidad  \
# 974  {'url': 'https://www.contratos.gov.co/consulta...       817000992-5
# 975  {'url': 'https://www.contratos.gov.co/consulta...       800026156-5
# 976  {'url': 'https://www.contratos.gov.co/consulta...         800100053
# 977  {'url': 'https://www.contratos.gov.co/consulta...         800016757
# 978  {'url': 'https://www.contratos.gov.co/consulta...       890982141-2
#
#     identificacion_del_contratista dpto_y_muni_contratista municipio_entidad  \
# 974                     9000714112               SANTANDER       PIEDECUESTA
# 975                      901051754               ANTIOQUIA             OLAYA
# 976                       80057163                  TOLIMA         CHAPARRAL
# 977                      901339663                  BOYACA            SAMACA
# 978                      811013361               ANTIOQUIA         ANGOSTURA
#
#                 nom_razon_social_contratista estado_del_proceso
# 974   INGENIERIA Y SERVICIOS DE COLOMBIA SAS          LIQUIDADO
# 975  INSUMOS INMOBILIARIOS Y CAFETEROS S.A.S          LIQUIDADO
# 976          WILLIAM RICARDO MORALES ANDRADE          LIQUIDADO
# 977          CONSORCIO HUELLAS SANTO DOMINGO          LIQUIDADO
# 978           CONSTRUCCIONES D.L. Y CIA LTDA          LIQUIDADO

# %% [markdown]
# **Información general del conjunto de datos:**
#
# * Filas: 979 contratos.
# * Columnas: 28 atributos o características del contrato.
# * Tipos de datos:
#
#   * 9 columnas numéricas (int64): incluyen información financiera y de tiempo, como *cuantia_proceso, cuantia_contrato, valor_total_de_adiciones, y plazo_de_ejec_del_contrato*.
#   * 19 columnas tipo texto (object): detalles textuales como *nombre_de_la_entidad, departamento_entidad, modalidad, fechas y estado del proceso.*
#
# * Valores nulos: Ninguna columna tiene valores nulos, todas las columnas están completamente llenas.
#
# **¿Qué variable no estan en el formato correcto?**
#
# * var1
# * var2
# * ...
#
# Esta información es valiosa para luego realizar el procesamiento y preparación de los datos.

# %%
# Comprueba la estructura de las columnas (tipos de datos y nombres).
# Analiza la forma del dataset (número de filas y columnas).
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   uid                             979 non-null    object
#  1   nombre_de_la_entidad            979 non-null    object
#  2   departamento_entidad            979 non-null    object
#  3   orden_entidad                   979 non-null    object
#  4   modalidad                       979 non-null    object
#  5   causal_contratacion_directa     979 non-null    object
#  6   objeto_a_contratar              979 non-null    object
#  7   detalle_objeto                  979 non-null    object
#  8   cuantia_proceso                 979 non-null    int64
#  9   cuantia_contrato                979 non-null    int64
#  10  valor_total_de_adiciones        979 non-null    int64
#  11  valor_contrato_con_adiciones    979 non-null    int64
#  12  anno_firma                      979 non-null    int64
#  13  fecha_firma                     979 non-null    object
#  14  fecha_ini_ejec_contrato         979 non-null    object
#  15  plazo_de_ejec_del_contrato      979 non-null    int64
#  16  rango_de_ejec_del_contrato      979 non-null    object
#  17  tiempo_adiciones_en_dias        979 non-null    int64
#  18  tiempo_adiciones_en_meses       979 non-null    int64
#  19  fecha_fin_ejec_contrato         979 non-null    object
#  20  id_adjudicacion                 979 non-null    int64
#  21  urlproceso                      979 non-null    object
#  22  nit_de_la_entidad               979 non-null    object
#  23  identificacion_del_contratista  979 non-null    object
#  24  dpto_y_muni_contratista         979 non-null    object
#  25  municipio_entidad               979 non-null    object
#  26  nom_razon_social_contratista    979 non-null    object
#  27  estado_del_proceso              979 non-null    object
# dtypes: int64(9), object(19)
# memory usage: 214.3+ KB

# %% [markdown]
# ### Análisis de las Desviaciones Costo

# %% [markdown]
# El propósito de este análisis es comprender el comportamiento de las desviaciones. Para ello, se generan estadísticas sobre el total de proyectos con desviaciones, el porcentaje que representan respecto al total y la magnitud de dichas desviaciones tanto en términos absolutos como relativos.

# %%
# Crear una columna binaria para indicar sobrecostos
datos['tiene_sobrecosto'] = datos['valor_total_de_adiciones'] > 0
datos['tiene_sobrecosto']
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# Name: tiene_sobrecosto, Length: 979, dtype: bool

# %%
# Proyectos con sobrecostos
datos['tiene_sobrecosto'].sum()
# Out:
# 187

# %%
# Proyectos con y sin sobrecostos
datos.groupby('tiene_sobrecosto').size()
# Out:
# tiene_sobrecosto
# False    792
# True     187
# dtype: int64

# %%
# Proporción de proyectos presentan sobrecostos
datos['tiene_sobrecosto'].mean()
# Out:
# 0.19101123595505617

# %%
# Magnitud de los sobrecostos
datos['valor_total_de_adiciones'].sum()
# Out:
# 32097532456

# %%
# Sobrecosto escalado millones
# 1e6: 1 millon
datos['valor_total_de_adiciones'].sum()/1e6
# Out:
# 32097.532456

# %%
# Escalar variables del valor del contrato en millones
datos['cuantia_proceso'] = datos['cuantia_proceso'] / 1e6
datos['cuantia_contrato'] = datos['cuantia_contrato'] / 1e6
datos['valor_total_de_adiciones'] = datos['valor_total_de_adiciones'] / 1e6
datos['valor_contrato_con_adiciones'] = datos['valor_contrato_con_adiciones'] / 1e6

# %%
# Filtrar contratos con sobrecostos
datos[datos['valor_total_de_adiciones'] > 0]
# Out:
#                          uid  \
# 3     20-11-10445399-9709897
# 4       20-21-20342-10910037
# 5    22-13-12893871-11958803
# 8        18-1-190669-7618772
# 12     15-11-3913923-3794831
# ..                       ...
# 953    18-13-8118609-7389776
# 957     22-21-30570-12314069
# 968      16-1-165152-5432603
# 969  21-11-11957595-11168118
# 978      19-21-12467-9123539
#
#                                   nombre_de_la_entidad departamento_entidad  \
# 3             BOYACA - ALCALDIA MUNICIPIO DE PACHAVITA               BOYACA
# 4               BOYACA - ALCALDIA MUNICIPIO DE CHIVATA               BOYACA
# 5    NORTE DE SANTANDER - ALCALDIA MUNICIPIO DE ABREGO   NORTE DE SANTANDER
# 8        SANTANDER - ALCALDIA MUNICIPIO DE BUCARAMANGA            SANTANDER
# 12          ANTIOQUIA - ALCALDIA MUNICIPIO DE RIONEGRO            ANTIOQUIA
# ..                                                 ...                  ...
# 953          CALDAS - ALCALDIA MUNICIPIO DE MANZANARES               CALDAS
# 957            ANTIOQUIA - ALCALDIA MUNICIPIO DE MACEO            ANTIOQUIA
# 968     CUNDINAMARCA - ALCALDIA MUNICIPIO DE TOCANCIPA         CUNDINAMARCA
# 969      META - ALCALDIA MUNICIPIO DE BARRANCA DE UPIA                 META
# 978        ANTIOQUIA - ALCALDIA MUNICIPIO DE ANGOSTURA            ANTIOQUIA
#
#                                orden_entidad  \
# 3    TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 4    TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 5    TERRITORIAL DISTRITAL MUNICIPAL NIVEL 3
# 8    TERRITORIAL DISTRITAL MUNICIPAL NIVEL 1
# 12   TERRITORIAL DISTRITAL MUNICIPAL NIVEL 2
# ..                                       ...
# 953  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 957  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 968  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 5
# 969  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 978  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
#
#                                              modalidad  \
# 3    SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 4                              LICITACION OBRA PUBLICA
# 5                          CONTRATACION MINIMA CUANTIA
# 8                                   LICITACION PUBLICA
# 12   SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# ..                                                 ...
# 953                        CONTRATACION MINIMA CUANTIA
# 957                            LICITACION OBRA PUBLICA
# 968                                 LICITACION PUBLICA
# 969  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 978                            LICITACION OBRA PUBLICA
#
#     causal_contratacion_directa                       objeto_a_contratar  \
# 3                   NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 4                   NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 5                   NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 8                   NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 12                  NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# ..                          ...                                      ...
# 953                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 957                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 968                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 969                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 978                 NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
#
#                                         detalle_objeto  cuantia_proceso  \
# 3    MANTENIMIENTO Y MEJORAMIENTO VIAS VEREDALES EN...       162.103043
# 4    MEJORAMIENTO DE LA VIA AVENIDA JIMENEZ - PONTE...       467.516765
# 5    MANTENIMIENTO Y MEJORAMIENTO DE LAS VIAS TERCI...        27.990806
# 8    CONSTRUCCION DE PLACA HUELLAS Y REPOSICION DE ...      1277.358628
# 12   PAVIMENTACION EN CONCRETO RIGIDO Y OBRAS COMPL...       289.381904
# ..                                                 ...              ...
# 953  CONTRATAR LAS OBRAS DE CONSTRUCCION DE 80ML DE...        21.800000
# 957  CONSTRUCCION DE PLACA HUELLA EN LA VEREDA GUAR...      1638.082033
# 968  CONSTRUCCION; REHABILITACION; AMPLIACION DE LA...     14000.000000
# 969  MANTENIMIENTO PERIODICO DE LAS DIFERENTES VIAS...       212.223685
# 978  CONSTRUCCION A TODO COSTO DE UN (1) KILOMETRO ...       398.344885
#
#      cuantia_contrato  valor_total_de_adiciones  valor_contrato_con_adiciones  \
# 3          162.084746                 75.000000                    237.084746
# 4          441.787828                158.201644                    599.989472
# 5           23.508500                 11.590625                     35.099125
# 8         1250.571151                400.000000                   1650.571151
# 12         288.881726                144.440863                    433.322589
# ..                ...                       ...                           ...
# 953         21.784000                  5.967500                     27.751500
# 957       1573.580425                 49.546545                   1623.126970
# 968      13971.578090               6971.817467                  20943.395557
# 969        212.065482                 64.967764                    277.033246
# 978        398.330315                 62.400000                    460.730315
#
#      anno_firma              fecha_firma  fecha_ini_ejec_contrato  \
# 3          2020  2020-03-10T00:00:00.000  2020-04-01T00:00:00.000
# 4          2021  2021-03-08T00:00:00.000  2021-03-11T00:00:00.000
# 5          2022  2022-02-18T00:00:00.000  2022-02-18T00:00:00.000
# 8          2018  2018-07-10T00:00:00.000  2018-08-27T00:00:00.000
# 12         2015  2015-07-13T00:00:00.000  2015-07-27T00:00:00.000
# ..          ...                      ...                      ...
# 953        2018  2018-06-06T00:00:00.000  2018-06-06T00:00:00.000
# 957        2022  2022-06-10T00:00:00.000  2022-09-01T00:00:00.000
# 968        2016  2016-12-23T00:00:00.000  2016-12-23T00:00:00.000
# 969        2021  2021-06-10T00:00:00.000  2021-06-17T00:00:00.000
# 978        2019  2019-09-16T00:00:00.000  2019-10-16T00:00:00.000
#
#      plazo_de_ejec_del_contrato rango_de_ejec_del_contrato  \
# 3                             3                          M
# 4                             1                          M
# 5                             2                          M
# 8                             3                          M
# 12                            2                          M
# ..                          ...                        ...
# 953                          45                          D
# 957                           4                          M
# 968                          12                          M
# 969                           2                          M
# 978                           2                          M
#
#      tiempo_adiciones_en_dias  tiempo_adiciones_en_meses  \
# 3                          45                          0
# 4                           0                          1
# 5                           0                          0
# 8                          30                          0
# 12                          0                          1
# ..                        ...                        ...
# 953                         0                          0
# 957                         0                          2
# 968                        45                          7
# 969                        15                          0
# 978                        30                          5
#
#      fecha_fin_ejec_contrato  id_adjudicacion  \
# 3    2020-08-01T00:00:00.000          9709897
# 4    2021-05-11T00:00:00.000         10910037
# 5    2022-04-18T00:00:00.000         11958803
# 8    2018-12-27T00:00:00.000          7618772
# 12   2015-10-27T00:00:00.000          3794831
# ..                       ...              ...
# 953  2018-07-21T00:00:00.000          7389776
# 957  2023-03-01T00:00:00.000         12314069
# 968  2018-08-23T00:00:00.000          5432603
# 969  2021-08-17T00:00:00.000         11168118
# 978  2020-06-16T00:00:00.000          9123539
#
#                                             urlproceso nit_de_la_entidad  \
# 3    {'url': 'https://www.contratos.gov.co/consulta...         800028461
# 4    {'url': 'https://www.contratos.gov.co/consulta...       800014989-1
# 5    {'url': 'https://www.contratos.gov.co/consulta...       890981195-5
# 8    {'url': 'https://www.contratos.gov.co/consulta...         890201222
# 12   {'url': 'https://www.contratos.gov.co/consulta...       890204646-3
# ..                                                 ...               ...
# 953  {'url': 'https://www.contratos.gov.co/consulta...       800094711-3
# 957  {'url': 'https://www.contratos.gov.co/consulta...       890210947-1
# 968  {'url': 'https://www.contratos.gov.co/consulta...       800093439-1
# 969  {'url': 'https://www.contratos.gov.co/consulta...       800152577-1
# 978  {'url': 'https://www.contratos.gov.co/consulta...       890982141-2
#
#     identificacion_del_contratista dpto_y_muni_contratista municipio_entidad  \
# 3                        900485495                  BOYACA         PACHAVITA
# 4                        901451682                  BOYACA           CHIVATA
# 5                       9009652722               SANTANDER            ABREGO
# 8                        901193544               SANTANDER       BUCARAMANGA
# 12                     900434281-0               ANTIOQUIA          RIONEGRO
# ..                             ...                     ...               ...
# 953                       15985491                  CALDAS        MANZANARES
# 957                      901603044             BOGOTA D.C.             MACEO
# 968                      901037219            CUNDINAMARCA         TOCANCIPA
# 969                      900855280                    META  BARRANCA DE UPIA
# 978                      811013361               ANTIOQUIA         ANGOSTURA
#
#                           nom_razon_social_contratista estado_del_proceso  \
# 3                    SAGA S.A.S, CONSTRUIMOS EL FUTURO          LIQUIDADO
# 4                          UNION TEMPORAL CHIVATA 2020          LIQUIDADO
# 5    ISMACOM S.A.S  NIT: 900965272-2 REPRESENTADA L...          LIQUIDADO
# 8                       CONSORCIO VARGAS NP INGENIERIA          LIQUIDADO
# 12                        CONSTRUCCIONES SEGURAS S.A.S          LIQUIDADO
# ..                                                 ...                ...
# 953                      CARLOS EGDARDO HURTADO JIMNEZ          LIQUIDADO
# 957                                 CONSORCIO VIAS V&S          LIQUIDADO
# 968                               CONSORCIO PIEDEMONTE          LIQUIDADO
# 969                                        TRANSUMICOM          LIQUIDADO
# 978                     CONSTRUCCIONES D.L. Y CIA LTDA          LIQUIDADO
#
#      tiene_sobrecosto
# 3                True
# 4                True
# 5                True
# 8                True
# 12               True
# ..                ...
# 953              True
# 957              True
# 968              True
# 969              True
# 978              True
#
# [187 rows x 29 columns]

# %%
# Filtrar datos de sobrecotos
sobrecostos = datos[datos['valor_total_de_adiciones'] > 0]['valor_total_de_adiciones']

# Resumen estadístico de los sobrecostos de los proyectos
sobrecostos.describe()
# Out:
# count     187.000000
# mean      171.644559
# std       685.696784
# min         2.460000
# 25%        12.963107
# 50%        39.567801
# 75%        90.187531
# max      6971.817467
# Name: valor_total_de_adiciones, dtype: float64

# %% [markdown]
# En la distribución de los sobrecostos se puede observar la presencia de datos extremos (outliers). Por tanto, es el proceso de limpieza es necesario incluir una tarea para el tratamiento de este tipo de observaciones.
#
# > <font color="green"> **Tip Práctico:** Tras la exploración inicial de los datos, elabore una lista de tareas de limpieza y ejecútelas.  Itere sobre estas tareas hasta que el comportamiento de las variables se estabilice.</font>

# %%
# Distribución de las desviaciones en costo
sns.histplot(sobrecostos, kde=True)
plt.title('Distribución de Sobrecostos')
plt.xlabel('Sobrecostos (millones)')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Para identificar posibles outliers puede calcular los percentiles más altos (90%-99%)

# %%
# Calcular los percentiles del sobrecosto entre el 90% y 99% con incrementos en 1%
sobrecostos.quantile(np.arange(0.9, 1, 0.01))
# Out:
# 0.90     218.757687
# 0.91     229.398848
# 0.92     300.724781
# 0.93     349.566432
# 0.94     526.000000
# 0.95     591.463125
# 0.96     615.299434
# 0.97     918.932569
# 0.98     979.824996
# 0.99    2828.814230
# Name: valor_total_de_adiciones, dtype: float64

# %%
# Gráfico de caja para la distribución de los sobrecostos
sns.boxplot(sobrecostos)
plt.title('Distribución de Sobrecostos')
plt.ylabel('Sobrecostos (millones)')
plt.show()

# %% [markdown]
# > <font color="green">**Tip Práctico:** aplicar una transformación logarítmica a las variables numéricas que presentan cambios significativos en el orden de magnitud para reducir la asimetría y la variabilidad de los datos. Esto ayuda a estabilizar la varianza, resaltar patrones que podrían estar ocultos debido a valores extremos y mejorar el rendimiento de modelos estadísticos o de machine learning al aproximar las distribuciones a una forma más normal. Sin embargo, esta transformación solo debe aplicarse a variables positivas y debe interpretarse con cuidado, ya que los valores transformados estarán en una escala diferente a la original.</font>

# %%
# Gráfico de caja para la distribución del sobrecosto
sns.boxplot(sobrecostos)
plt.title('Distribución de Sobrecostos')
plt.ylabel('Log. Sobrecostos (millones)')
plt.yscale('log') # Transformación logarítmica del eje y
plt.show()

# %% [markdown]
# **Desviación Porcentual del Valor del Proyecto**
#
# Calcular una métrica porcentual para medir la desviación en costo es fundamental porque permite estandarizar la comparación entre proyectos de diferentes tamaños y cuantías. Mientras que una desviación absoluta solo muestra el cambio en términos monetarios, el cálculo porcentual refleja la magnitud del sobrecosto relativo al presupuesto original, lo cual facilita entender el impacto real de la desviación y comparar el desempeño financiero de distintos proyectos de manera más equitativa y comprensible.
#
# $$
# \text{% Desviación en Costo} = \left( \frac{\text{Valor Final del Contrato - Valor Inicial del Contrato}}{\text{Valor Inicial del Contrato}} \right) \times 100
# $$

# %%
# Generar un nueva columna con el sobrecosto porcentual respecto al valor del contrato
datos['sobrecosto_porcentual'] = ((datos['valor_contrato_con_adiciones'] - datos['cuantia_contrato']) / datos['cuantia_contrato']) * 100

# Resumen estadístico del sobrecosto porcentual
datos[datos['sobrecosto_porcentual'] > 0]['sobrecosto_porcentual'].describe()
# Out:
# count    187.000000
# mean      30.454412
# std       18.286685
# min        1.525025
# 25%       14.111720
# 50%       30.163888
# 75%       47.932447
# max      100.000000
# Name: sobrecosto_porcentual, dtype: float64

# %% [markdown]
# <font color="red">**Alerta!!!:** El sobrecosto porcentual muestra un máximo de 100%. La ley de contratación en Colombia indica que los contratos pueden tener adiciones de hasta un máximo del 50% del valor inicial del contrato. En este contexto esta restricción es una regla de "negocio" para detectar posibles errores e incosistencias.</font>

# %%
# Contratos que tienen un sobrecosto superior al 50%?
sum(datos['sobrecosto_porcentual'] > 50)
# Out:
# 5

# %%
# Filtrar contratos con sobrecostos superiores al 50%
datos[datos['sobrecosto_porcentual'] > 50]
# Out:
#                          uid                          nombre_de_la_entidad  \
# 99       16-1-160682-5104858  ANTIOQUIA - ALCALDIA MUNICIPIO DE COPACABANA
# 139    18-11-8406037-7858990    CESAR - ALCALDIA MUNICIPIO DE PUEBLO BELLO
# 664  22-12-13054252-12089130    SANTANDER - ALCALDIA MUNICIPIO DE RIONEGRO
# 689    18-11-8079890-7940639   CUNDINAMARCA - ALCALDIA MUNICIPIO DE SUPATA
# 693    15-11-4372051-5062390    ANTIOQUIA - ALCALDIA MUNICIPIO DE RIONEGRO
#
#     departamento_entidad                            orden_entidad  \
# 99             ANTIOQUIA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 3
# 139                CESAR  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 664            SANTANDER  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 689         CUNDINAMARCA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6
# 693            ANTIOQUIA  TERRITORIAL DISTRITAL MUNICIPAL NIVEL 2
#
#                                              modalidad  \
# 99                                  LICITACION PUBLICA
# 139  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 664            CONTRATACION DIRECTA (LEY 1150 DE 2007)
# 689  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
# 693  SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150...
#
#          causal_contratacion_directa                       objeto_a_contratar  \
# 99                       NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 139                      NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 664  URGENCIA MANIFIESTA (LITERAL A)  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 689                      NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
# 693                      NO DEFINIDO  TERRENOS, EDIFICIOS, ESTRUCTURAS Y VIAS
#
#                                         detalle_objeto  cuantia_proceso  \
# 99   CONSTRUCCION DE PLACA HUELLAS EN VIA TERCIARIA...       279.213220
# 139  CONTRATO DE OBRA PUBLICA PARA LA CONSTRUCCION ...       673.366714
# 664  MANTENIMIENTO Y REHABILITACION DE LAS VIAS TER...        98.848000
# 689  MEJORAMIENTO DE LA VIA QUE COMUNICA A LA VERED...        57.000000
# 693  CONSTRUCCION DE PLACA HUELLA EN LA ZONA RURAL ...       231.724402
#
#      cuantia_contrato  valor_total_de_adiciones  valor_contrato_con_adiciones  \
# 99         278.821920                139.410960                    418.232880
# 139         33.651592                 29.687572                     63.339164
# 664         98.848000                 80.000000                    178.848000
# 689         56.933965                 56.933965                    113.867930
# 693        213.185934                106.592967                    319.778901
#
#      anno_firma              fecha_firma  fecha_ini_ejec_contrato  \
# 99         2016  2016-09-19T00:00:00.000  2016-09-20T00:00:00.000
# 139        2018  2018-10-24T00:00:00.000  2018-11-02T00:00:00.000
# 664        2022  2022-04-27T00:00:00.000  2022-04-28T00:00:00.000
# 689        2018  2018-06-05T00:00:00.000  2018-06-20T00:00:00.000
# 693        2015  2015-12-16T00:00:00.000  2016-08-01T00:00:00.000
#
#      plazo_de_ejec_del_contrato rango_de_ejec_del_contrato  \
# 99                           75                          D
# 139                           2                          M
# 664                           2                          M
# 689                           2                          M
# 693                           1                          M
#
#      tiempo_adiciones_en_dias  tiempo_adiciones_en_meses  \
# 99                         15                          1
# 139                         0                          0
# 664                         0                          0
# 689                         0                          0
# 693                         0                          2
#
#      fecha_fin_ejec_contrato  id_adjudicacion  \
# 99   2017-01-18T00:00:00.000          5104858
# 139  2019-01-02T00:00:00.000          7858990
# 664  2022-06-28T00:00:00.000         12089130
# 689  2018-08-20T00:00:00.000          7940639
# 693  2016-11-01T00:00:00.000          5062390
#
#                                             urlproceso nit_de_la_entidad  \
# 99   {'url': 'https://www.contratos.gov.co/consulta...       No Definido
# 139  {'url': 'https://www.contratos.gov.co/consulta...       800103021-1
# 664  {'url': 'https://www.contratos.gov.co/consulta...         890204646
# 689  {'url': 'https://www.contratos.gov.co/consulta...         899999398
# 693  {'url': 'https://www.contratos.gov.co/consulta...       890204646-3
#
#     identificacion_del_contratista dpto_y_muni_contratista municipio_entidad  \
# 99                        71213480               ANTIOQUIA        COPACABANA
# 139                      824001624                   CESAR      PUEBLO BELLO
# 664                      901400219               SANTANDER          RIONEGRO
# 689                      900895806            CUNDINAMARCA            SUPATA
# 693                      900920718               ANTIOQUIA          RIONEGRO
#
#                           nom_razon_social_contratista estado_del_proceso  \
# 99                       GUSTAVO ADOLFO MUNOZ BETANCUR          LIQUIDADO
# 139                               CONSORCIO SANTA RITA          LIQUIDADO
# 664                                        INCEGRO SAS          LIQUIDADO
# 689  INGENIERIA EN CONSTRUCCIONES E INTERVENTORIAS ...          LIQUIDADO
# 693                                        900920718-1          LIQUIDADO
#
#      tiene_sobrecosto  sobrecosto_porcentual
# 99               True              50.000000
# 139              True              88.220409
# 664              True              80.932341
# 689              True             100.000000
# 693              True              50.000000

# %% [markdown]
# **Principales conclusiones:**
#
# * Contratos con sobrecostos: 187 (N = 979)
# * Porcentaje de contratos con sobrecostos: 19.1%
# * Total de sobrecostos: $32.097 millones de pesos
# * Promedio y mediana de sobrecostos por proyecto: Promedio de 171 millones y una mediana de 39 millones.
# * Variación de los sobrecostos: los sobrecostos oscilan entre 2.46 y 6.971 millones, con una desviación estándar de 685 millones, lo que indica una variación significativamente alta.
# * Sobrecosto porcentual respecto al valor inicial del contrato: los contratos presentan sobrecostos en promedio del 30.45% respecto al valor inicial.
#
#
# **Lista de tareas de limpieza pendiente:**
#
# * Revisar contratos con sobrecostos de más del 50%
# * Revisar contratos con sobrecostos extremos

# %% [markdown]
# ### Análisis de las Desviaciones en Tiempo

# %% [markdown]
# Ahora repitan el análisis que se desarrolló en las desviaciones en costo con las desviaciones en tiempo. De la exploración genere una lista de tareas de procesamiento y limpieza de datos. Además, señale posibles incosistencias.
#
# Antes vamos desarrolar algunas tareas de limpieza necesarias para el análisis:
#
# 1. Crear una columna para unificar las desviaciones en día
# 2. Unificar la duración del contrato en días.

# %%
# Crear una columna para unificar las desviaciones en día
datos['retrasos_dias'] = datos['tiempo_adiciones_en_dias'] + datos['tiempo_adiciones_en_meses']*30

# %%
# Verificar si la duración del contrato está en días (D) o meses (M) para asegurar la consistencia en el análisis posterior
datos.groupby(['rango_de_ejec_del_contrato']).size()
# Out:
# rango_de_ejec_del_contrato
# D    382
# M    597
# dtype: int64

# %%
# Unificar el rango de la duración del contrato
datos['duracion_contrato_dias'] = datos['plazo_de_ejec_del_contrato']
datos.loc[datos['rango_de_ejec_del_contrato'] == 'M', 'duracion_contrato_dias'] *= 30

# %%
# ¿Cuántos proyectos presentan retrasos?

# %%
# Crear una columna binaria para indicar retrasos

# %%
# Proyectos con y sin retrasos

# %%
# ¿Qué proporción de proyectos presentan retrasos?

# %%
# Filtrar contratos con retrasos

# %%
# Resumen estadístico de los retrasos

# %%
# Distribución de los retrasos

# %%
# Gráfico de caja para la distribución de los retrasos en los proyectos

# %% [markdown]
# **Desviación Porcentual de la Duración Inicial Proyecto**
#
#
# $$
# \text{% Desviación en Tiempo} = \left( \frac{\text{Duración Final del Contrato - Duración Inicial del Contrato}}{\text{Duración Inicial del Contrato}} \right) \times 100
# $$

# %%
# Generar un nueva columna con el retraso porcentual respecto a la duración inicial del contrato

# Resumen estadístico del retraso porcentual

# %% [markdown]
# <font color="red">**Alerta!!!:** Para las desviaciones en tiempo no existe la restricciones en tiempo ¿De qué manera se pueden identificar incosistencias?.</font>

# %% [markdown]
# Según su experiencia que porcentaje se debería considerar como atípico o extremos para el retraso porcentual del proyecto.

# %%
# ¿Cuantós contratos presentan retrasos extremos?

# %%
# Filtrar contratos con retrasos extremos

# %% [markdown]
# **Principales conclusiones:**
#
# * Contratos con retrasos:
# * Porcentaje de contratos con restrasos:
# * Promedio y mediana de retrasos por proyecto:
# * Variación de los retrasos:
# * Retraso porcentual respecto a la duración inicial del contrato
#
#
# **Lista de tareas de limpieza:**
#
# * Tarea 1:
# * Tarea 2:

# %% [markdown]
# ### Análisis de Desviaciones en Función de la Modalidad de Contratación

# %% [markdown]
# Este análisis se enfoca en examinar cómo la modalidad de contratación influye en las desviaciones en el tiempo de ejecución de los proyectos. Dado que las diferentes modalidades, como licitación pública o contratación directa, pueden implicar procesos administrativos y operativos distintos, es fundamental entender cómo estas diferencias afectan los presupuestos de los proyectos. El objetivo es identificar patrones en el comportamiento de las desviaciones en costo en función de la modalidad del contrato y explicar qué modalidades presentan mayores riesgos de sobrecosto dentro del conjunto de datos.

# %% [markdown]
# **Análisis de Desviaciones en Costo por Modalidad**

# %%
# Contratos por modalidad
datos['modalidad'].value_counts()
# Out:
# modalidad
# SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150 DE 2007)                                  400
# CONTRATACION MINIMA CUANTIA                                                              215
# LICITACION PUBLICA                                                                       166
# REGIMEN ESPECIAL                                                                          85
# LICITACION OBRA PUBLICA                                                                   71
# CONTRATACION DIRECTA (LEY 1150 DE 2007)                                                   34
# CONTRATOS Y CONVENIOS CON MAS DE DOS PARTES                                                4
# SELECCION ABREVIADA DEL LITERAL H DEL NUMERAL 2 DEL ARTICULO 2 DE LA LEY 1150 DE 2007      2
# CONCURSO DE DISENO ARQUITECTONICO                                                          1
# CONCURSO DE MERITOS ABIERTO                                                                1
# Name: count, dtype: int64

# %%
# Proporción de contratos por modalidad
datos['modalidad'].value_counts(normalize=True)
# Out:
# modalidad
# SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150 DE 2007)                                  0.408580
# CONTRATACION MINIMA CUANTIA                                                              0.219612
# LICITACION PUBLICA                                                                       0.169561
# REGIMEN ESPECIAL                                                                         0.086823
# LICITACION OBRA PUBLICA                                                                  0.072523
# CONTRATACION DIRECTA (LEY 1150 DE 2007)                                                  0.034729
# CONTRATOS Y CONVENIOS CON MAS DE DOS PARTES                                              0.004086
# SELECCION ABREVIADA DEL LITERAL H DEL NUMERAL 2 DEL ARTICULO 2 DE LA LEY 1150 DE 2007    0.002043
# CONCURSO DE DISENO ARQUITECTONICO                                                        0.001021
# CONCURSO DE MERITOS ABIERTO                                                              0.001021
# Name: proportion, dtype: float64

# %% [markdown]
# > <font color="green">**Tip Práctico:** En una variable categórica, es posible agrupar las categorías que representan menos del 1% del total, ya que su impacto en el análisis suele ser mínimo. Además, es importante cuestionar por qué estas categorías tienen baja relevancia; esto podría justificar su agrupación o incluso su eliminación del conjunto de datos si no aportan valor significativo al análisis.</font>

# %%
# Calcular la frecuencia de cada modalidad
modalidad_counts = datos['modalidad'].value_counts(normalize=True)

# Identificar modalidades con menos de 1% contratos
low_count_modalities = modalidad_counts[modalidad_counts < 0.01].index

# Reemplazar las modalidades con menos de 1% contratos por 'OTROS'
datos['modalidad_reducido'] = datos['modalidad'].replace(low_count_modalities, 'OTROS')

# Mostrar la nueva tabla de frecuencia
datos['modalidad_reducido'].value_counts()
# Out:
# modalidad_reducido
# SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150 DE 2007)    400
# CONTRATACION MINIMA CUANTIA                                215
# LICITACION PUBLICA                                         166
# REGIMEN ESPECIAL                                            85
# LICITACION OBRA PUBLICA                                     71
# CONTRATACION DIRECTA (LEY 1150 DE 2007)                     34
# OTROS                                                        8
# Name: count, dtype: int64

# %%
# Grafíco de barras de las modalidades de contratación
sns.countplot(data = datos, x = 'modalidad_reducido')
plt.title('Proyectos por Modalidad de Contratación')
plt.xlabel('Frecuencia')
plt.ylabel('Modalidad')
plt.show()

# %%
# Grafíco de barras de las modalidades de contratación
sns.countplot(data = datos, x = 'modalidad_reducido')
plt.title('Proyectos por Modalidad de Contratación')
plt.xlabel('Frecuencia')
plt.ylabel('Modalidad')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# > <font color="green">**Tip Práctico:** Ordenar las categorías en un gráfico de barras, ya sea de mayor a menor o viceversa, mejora significativamente la visualización de los datos. Esto facilita la comparación entre categorías, resalta tendencias y permite identificar rápidamente los valores más altos y más bajos.  Además, considera utilizar barras horizontales, especialmente si las etiquetas de las categorías son largas, ya que esto mejora la legibilidad y hace que el gráfico sea más fácil de interpretar. Un gráfico ordenado y bien presentado ayuda a comunicar la información de manera más clara y efectiva.</font>

# %%
# Gráfico de Barras Horizontales
datos['modalidad_reducido'].value_counts(ascending=True).plot.barh()
plt.title('Proyectos por Modalidad de Contratación')
plt.xlabel('Frecuencia')
plt.ylabel('Modalidad')
plt.show()

# %%
# Gráfico de torta
datos['modalidad_reducido'].value_counts(ascending=True).plot.pie(autopct='%1.1f%%')
plt.title('Proyectos por Modalidad de Contratación')
plt.show()

# %% [markdown]
# > <font color="green">**Tip Práctico:** Revise las variables categórica con el fin de identificar tareas de estandarización (agrupar, reducir, estandarizar categorías, entre otros). En este caso podriamos combinar las modalidades de LICITACION PUBLICA Y LICITACION DE OBRA PUBLICA.</font>

# %%
# Proyectos con desviaciones en costo por modalidad de contratación
proyectos_desv_costo = pd.crosstab(datos['modalidad_reducido'], datos['tiene_sobrecosto'])
proyectos_desv_costo
# Out:
# tiene_sobrecosto                                    False  True
# modalidad_reducido
# CONTRATACION DIRECTA (LEY 1150 DE 2007)                30      4
# CONTRATACION MINIMA CUANTIA                           185     30
# LICITACION OBRA PUBLICA                                50     21
# LICITACION PUBLICA                                    124     42
# OTROS                                                   8      0
# REGIMEN ESPECIAL                                       78      7
# SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150 ...    317     83

# %%
# Porcentaje de proyectos con desviaciones en costo por modalidad de contratación
proyectos_desv_costo_perc = pd.crosstab(datos['modalidad_reducido'], datos['tiene_sobrecosto'], normalize='index')
proyectos_desv_costo_perc
# Out:
# tiene_sobrecosto                                       False     True
# modalidad_reducido
# CONTRATACION DIRECTA (LEY 1150 DE 2007)             0.882353  0.117647
# CONTRATACION MINIMA CUANTIA                         0.860465  0.139535
# LICITACION OBRA PUBLICA                             0.704225  0.295775
# LICITACION PUBLICA                                  0.746988  0.253012
# OTROS                                               1.000000  0.000000
# REGIMEN ESPECIAL                                    0.917647  0.082353
# SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150 ...  0.792500  0.207500

# %%
# Gráfico de barras de las desviaciones en costo por modalidad
proyectos_desv_costo.plot.barh()
plt.legend(loc='lower right')
plt.title('Proyectos con Desviaciones en Costo por Modalidad')
plt.ylabel('Modalidad')
plt.xlabel('Frecuencia')
plt.show()

# %%
# Gráfico de barras agrupadas para mostrar la proporción de proyectos
# con desviaciones en costo por modalidad
proyectos_desv_costo_perc.plot.barh(stacked=True)
plt.title('Proyectos con Desviaciones en Costo por Modalidad')
plt.ylabel('Modalidad')
plt.xlabel('Proporción')
plt.legend(loc='lower right')
plt.show()

# %%
# Sobrecosto porcentual por modalidad
sobrecostos_modalidad = datos.loc[datos['sobrecosto_porcentual'] > 0, ['modalidad','sobrecosto_porcentual']]
sobrecostos_modalidad.groupby('modalidad')['sobrecosto_porcentual'].mean().sort_values(ascending=False)
# Out:
# modalidad
# CONTRATACION DIRECTA (LEY 1150 DE 2007)                    55.379930
# CONTRATACION MINIMA CUANTIA                                35.481702
# SELECCION ABREVIADA DE MENOR CUANTIA (LEY 1150 DE 2007)    34.125097
# REGIMEN ESPECIAL                                           28.356730
# LICITACION PUBLICA                                         24.646579
# LICITACION OBRA PUBLICA                                    16.331797
# Name: sobrecosto_porcentual, dtype: float64

# %%
# Sobrecosto porcentual por modalidad
sns.boxplot(data=sobrecostos_modalidad, x='sobrecosto_porcentual', y='modalidad')
plt.title('Sobrecosto Porcentual por Modalidad')
plt.xlabel('Sobrecosto Porcentual')
plt.ylabel('Modalidad')
plt.show()

# %% [markdown]
# **Conclusiones:**
#
# * C1.
# * C2.
# * C3.
# * C4.
# * C5.
#
# **Lista de tareas de limpieza:**
#
# * Tarea 1:
# * Tarea 2:

# %% [markdown]
# **Análisis de Desviaciones en Tiempo por Modalidad**

# %%
# Proyectos con desviaciones en tiempo por modalidad de contratación

# %%
# Porcentaje de proyectos con desviaciones en tiempo por modalidad de contratación

# %%
# Gráfico de proyectos con desviaciones en tiempo por modalidad

# %%
# Gráfico barras del porcentaje de desviaciones en tiempo por modalidad

# %%
# Restraso porcentual promedio por modalidad

# %%
# Gráfico de caja: Retraso porcentual por modalidad

# %% [markdown]
# ### Análisis de Desviaciones en Función del Valor del Contrato

# %%
# Resumen estadístico del valor del contrato
datos['cuantia_contrato'].describe()
# Out:
# count      979.000000
# mean       561.916993
# std       2795.751484
# min         20.002440
# 25%         31.832085
# 50%        100.689586
# 75%        271.085014
# max      51937.799600
# Name: cuantia_contrato, dtype: float64

# %%
# Histograma del valor del contrato
sns.histplot(datos['cuantia_contrato'], kde=True)
plt.title('Distribución del Valor del Contrato')
plt.xlabel('Valor del Contrato')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Histograma del valor del contrato
sns.boxplot(x=datos['cuantia_contrato'])
plt.xscale('log')
plt.title('Distribución del Valor del Contrato')
plt.xlabel('Valor del Contrato')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# > <font color="green">**Tip Práctico:** La discretización de variables numéricas, como la cuantía del contrato, puede facilitar su análisis al agrupar los valores en categorías significativas. Esto permite comparar de forma más sencilla segmentos de datos (por ejemplo, contratos pequeños, medianos y grandes) y observar tendencias, patrones o relaciones que podrían no ser evidentes con los valores continuos originales. Al definir estos rangos de manera lógica (e.g., cuantías bajas, medias y altas), también puedes mejorar la interpretabilidad de los resultados y simplificar el análisis exploratorio y visualización de datos.</font>

# %%
# Discretizar la variable del valor del contrato en los intervalos de 20, 100, 500, 1000, 5000, 10000
datos['cuantia_contrato_discreta'] = pd.cut(datos['cuantia_contrato'], bins=[20, 100, 500, 1000, 5000, 10000, np.infty])

# %%
# Proyectos según el rango del valor del contrato
datos.groupby(['cuantia_contrato_discreta']).size()
# Out:
# cuantia_contrato_discreta
# (20.0, 100.0]        488
# (100.0, 500.0]       345
# (500.0, 1000.0]       64
# (1000.0, 5000.0]      66
# (5000.0, 10000.0]      6
# (10000.0, inf]        10
# dtype: int64

# %%
# Distribución de proyectos según el rango del valor del contrato
datos.groupby(['cuantia_contrato_discreta']).size().plot.bar()
plt.title('Proyectos por Valor del Contrato')
plt.xlabel('Valor del Contrato')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Resumen del valor del contrato vs variable binaria que indica si hay o no sobrecosto
datos.groupby('tiene_sobrecosto')['cuantia_contrato'].describe()
# Out:
#                   count        mean          std        min        25%  \
# tiene_sobrecosto
# False             792.0  554.076190  3008.272204  20.002440  28.000000
# True              187.0  595.125101  1615.949511  20.151616  59.558589
#
#                          50%         75%          max
# tiene_sobrecosto
# False              98.645950  250.049380  51937.79960
# True              192.852426  442.569274  13971.57809

# %%
# Gráfico de caja del valor del contrato vs variable binaria que indica si hay o no sobrecosto
sns.boxplot(data=datos, x='tiene_sobrecosto', y='cuantia_contrato')
plt.title('Valor del Contrato vs Sobrecosto')
plt.xlabel('Valor del Contrato')
plt.ylabel('Sobrecosto')
plt.yscale('log')
plt.show()

# %%
# Proyectos con desviación en costo según el rango del valor del contrato
pd.crosstab(datos['cuantia_contrato_discreta'], datos['tiene_sobrecosto'])
# Out:
# tiene_sobrecosto           False  True
# cuantia_contrato_discreta
# (20.0, 100.0]                423     65
# (100.0, 500.0]               261     84
# (500.0, 1000.0]               50     14
# (1000.0, 5000.0]              46     20
# (5000.0, 10000.0]              4      2
# (10000.0, inf]                 8      2

# %%
# Porcentaje de Proyectos con desviación en costo según el rango del valor del contrato
pd.crosstab(datos['cuantia_contrato_discreta'], datos['tiene_sobrecosto'], normalize='index')
# Out:
# tiene_sobrecosto              False     True
# cuantia_contrato_discreta
# (20.0, 100.0]              0.866803  0.133197
# (100.0, 500.0]             0.756522  0.243478
# (500.0, 1000.0]            0.781250  0.218750
# (1000.0, 5000.0]           0.696970  0.303030
# (5000.0, 10000.0]          0.666667  0.333333
# (10000.0, inf]             0.800000  0.200000

# %%
# Gráfico del porcentaje de proyectos con sobrecostos según el rango del valor del contrato
datos.groupby(['cuantia_contrato_discreta'])['tiene_sobrecosto'].mean().plot.line(marker='o')
plt.title('Porcentaje de Proyectos con Desviación en Costo según Valor del Contrato')
plt.xlabel('Valor del Contrato')
plt.xticks(rotation=45)  # Rota las etiquetas del eje x
plt.ylabel('Porcentaje')
plt.show()

# %%
# Filtro de los datos de sobrecostos
sobrecostos = datos.loc[datos['sobrecosto_porcentual'] > 0, ['cuantia_contrato', 'cuantia_contrato_discreta','sobrecosto_porcentual']]
sobrecostos
# Out:
#      cuantia_contrato cuantia_contrato_discreta  sobrecosto_porcentual
# 3          162.084746            (100.0, 500.0]              46.272090
# 4          441.787828            (100.0, 500.0]              35.809417
# 5           23.508500             (20.0, 100.0]              49.303975
# 8         1250.571151          (1000.0, 5000.0]              31.985385
# 12         288.881726            (100.0, 500.0]              50.000000
# ..                ...                       ...                    ...
# 953         21.784000             (20.0, 100.0]              27.393959
# 957       1573.580425          (1000.0, 5000.0]               3.148650
# 968      13971.578090            (10000.0, inf]              49.900000
# 969        212.065482            (100.0, 500.0]              30.635709
# 978        398.330315            (100.0, 500.0]              15.665391
#
# [187 rows x 3 columns]

# %%
sns.boxplot(data=sobrecostos, x='sobrecosto_porcentual', y='cuantia_contrato_discreta')
plt.title('Sobrecosto Porcentual vs Valor del Contrato')
plt.xlabel('Valor del Contrato')
plt.ylabel('Sobrecosto Porcentual')
plt.show()

# %% [markdown]
# ### Análisis de correlación entre la cuantía del contrato, la duración y el sobrecosto porcentual

# %%
# Filtrar datos con sobrecostos
sobrecosto = datos.loc[datos['sobrecosto_porcentual'] > 0, ['cuantia_contrato','duracion_contrato_dias','sobrecosto_porcentual']]
sobrecosto
# Out:
#      cuantia_contrato  duracion_contrato_dias  sobrecosto_porcentual
# 3          162.084746                      90              46.272090
# 4          441.787828                      30              35.809417
# 5           23.508500                      60              49.303975
# 8         1250.571151                      90              31.985385
# 12         288.881726                      60              50.000000
# ..                ...                     ...                    ...
# 953         21.784000                      45              27.393959
# 957       1573.580425                     120               3.148650
# 968      13971.578090                     360              49.900000
# 969        212.065482                      60              30.635709
# 978        398.330315                      60              15.665391
#
# [187 rows x 3 columns]

# %%
# Gráficos de dispersión entre pares de variables
sns.pairplot(sobrecosto)
plt.show()

# %%
# Matriz de correlación entre variables
sobrecosto.corr()
# Out:
#                         cuantia_contrato  duracion_contrato_dias  \
# cuantia_contrato                1.000000                0.665003
# duracion_contrato_dias          0.665003                1.000000
# sobrecosto_porcentual          -0.032652               -0.179205
#
#                         sobrecosto_porcentual
# cuantia_contrato                    -0.032652
# duracion_contrato_dias              -0.179205
# sobrecosto_porcentual                1.000000

# %%
#. Gráfico de correlación
sns.heatmap(sobrecosto.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Taller en Clase.
#
# Desarrolle un análisis exploratorio de las desviaciones en tiempo y costo con las variables:
#
# * Intesidad del Proyecto
# $$
# \text{Intesidad =} \frac{\text{Valor del Contrato}}{\text{Duración}}
# $$
# * Año de firma del contrato
# * Mes de firma del contrato
# * Departamento
# * Orden de la entidad

# %%
datos

# %%
# Convertir fecha de firma del contrato a formato fecha
datos['fecha_firma'] = pd.to_datetime(datos['fecha_firma'])

# Extraer el mes de firma del contrato
datos['mes_firma'] = datos['fecha_firma'].dt.month
